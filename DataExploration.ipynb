# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import ROOT as R
R.enableJSVis()
# Out:
# Welcome to JupyROOT 6.18/00

# %%
#R.disableJSVis()

# %%
#from root_numpy import tree2array, root2array
#a = root2array(filenames = "data/BlueLaser_2017_rereco_v2_newformat.root", treename="ntu", start=0, stop=10)

# %%
f = R.TFile("data/BlueLaser_2017_rereco_v2_newformat.root")
t = f.Get("ntu")

# %%
t.Print()
# Out:
# ******************************************************************************
# *Tree    :ntu       : Dump of Laser data from file                           *
# *Entries :     7264 : Total =     11022543941 bytes  File  Size = 3068140965 *
# *        :          : Tree compression factor =   3.59                       *
# ******************************************************************************
# *Br    0 :run       : run/I                                                  *
# *Entries :     7264 : Total  Size=      38342 bytes  File Size  =      19193 *
# *Baskets :      101 : Basket Size=      36713 bytes  Compression=   1.88     *
# *............................................................................*
# *Br    1 :run_timestart : run_time_start/I                                   *
# *Entries :     7264 : Total  Size=      39395 bytes  File Size  =      24759 *
# *Baskets :      101 : Basket Size=      36713 bytes  Compression=   1.50     *
# ...

# %%
c = R.TCanvas("c1")
t.Draw("fill_num", "ix==20 && iy==20 && iz==1")
# Out:
# 7264
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c1

# %%
c.Draw()
# Out:
# <div id="root_plot_20"
#      style="width: 696px; height: 472px">
# </div>
#
# <script>
#  requirejs.config({
#      paths: {
#        'JSRootCore' : 'https://root.cern.ch/js/notebook//scripts/JSRootCore',
#      }
#    });
#  require(['JSRootCore'],
#      function(Core) {
# ...

# %%
c = R.TCanvas("c1")
t.Draw("ix:iy","", "colz")
c.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c1
# <div id="root_plot_3"
#      style="width: 696px; height: 472px">
# </div>
#
# <script>
#  requirejs.config({
#      paths: {
#        'JSRootCore' : 'https://root.cern.ch/js/notebook//scripts/JSRootCore',
#      }
#    });
#  require(['JSRootCore'],
#      function(Core) {
# ...

# %%
c = R.TCanvas("c1")
t.Draw("las_id", "ix==20 && iy==20")
c.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c1
# <div id="root_plot_6"
#      style="width: 696px; height: 472px">
# </div>
#
# <script>
#  requirejs.config({
#      paths: {
#        'JSRootCore' : 'https://root.cern.ch/js/notebook//scripts/JSRootCore',
#      }
#    });
#  require(['JSRootCore'],
#      function(Core) {
# ...

# %%
c = R.TCanvas("c1")
t.Draw("lumi:run")
c.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c1

# %%
c = R.TCanvas("c1")
t.Draw("run")
c.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c1

# %%
c = R.TCanvas("c1")
t.Draw("lumi:time[0]")
c.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c1
# <div id="root_plot_7"
#      style="width: 696px; height: 472px">
# </div>
#
# <script>
#  requirejs.config({
#      paths: {
#        'JSRootCore' : 'https://root.cern.ch/js/notebook//scripts/JSRootCore',
#      }
#    });
#  require(['JSRootCore'],
#      function(Core) {
# ...

# %% [markdown]
# ## Time[0] is the same as all the other time[n]

# %%
c = R.TCanvas("c1")
t.Draw("time[80]:time[0]")
c.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c1
# <div id="root_plot_8"
#      style="width: 696px; height: 472px">
# </div>
#
# <script>
#  requirejs.config({
#      paths: {
#        'JSRootCore' : 'https://root.cern.ch/js/notebook//scripts/JSRootCore',
#      }
#    });
#  require(['JSRootCore'],
#      function(Core) {
# ...

# %% [markdown]
# ## Fill_time is the start of the fill

# %%
c = R.TCanvas("c1")
t.Draw("nrv:fill_time", "fill_time > 0 && ix==20 && iy==20 && iz==0")
c.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c1
# <div id="root_plot_15"
#      style="width: 696px; height: 472px">
# </div>
#
# <script>
#  requirejs.config({
#      paths: {
#        'JSRootCore' : 'https://root.cern.ch/js/notebook//scripts/JSRootCore',
#      }
#    });
#  require(['JSRootCore'],
#      function(Core) {
# ...

# %%
c = R.TCanvas("c1")
t.Draw("nrv:(time[0] - fill_time_stablebeam):time[0]", "fill_time > 0 && ix==20 && iy==20 && iz==0")
c.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c1
# <div id="root_plot_19"
#      style="width: 696px; height: 472px">
# </div>
#
# <script>
#  requirejs.config({
#      paths: {
#        'JSRootCore' : 'https://root.cern.ch/js/notebook//scripts/JSRootCore',
#      }
#    });
#  require(['JSRootCore'],
#      function(Core) {
# ...

# %%
c = R.TCanvas("c1")
t.Draw("nrv:lumi", "lumi > 0 && ix==20 && iy==20 && iz==0")
c.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c1
# <div id="root_plot_16"
#      style="width: 696px; height: 472px">
# </div>
#
# <script>
#  requirejs.config({
#      paths: {
#        'JSRootCore' : 'https://root.cern.ch/js/notebook//scripts/JSRootCore',
#      }
#    });
#  require(['JSRootCore'],
#      function(Core) {
# ...

# %%
c = R.TCanvas("c1")
t.Draw("time[0]/fill_time_stablebeam>>h(100, 1, 1.0001)")
c.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c1
# <div id="root_plot_10"
#      style="width: 696px; height: 472px">
# </div>
#
# <script>
#  requirejs.config({
#      paths: {
#        'JSRootCore' : 'https://root.cern.ch/js/notebook//scripts/JSRootCore',
#      }
#    });
#  require(['JSRootCore'],
#      function(Core) {
# ...

# %%
c = R.TCanvas("c1")
t.Draw("(time[0]- fill_time)/fill_time", "fill_time>0")
c.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c1
# <div id="root_plot_42"
#      style="width: 696px; height: 472px">
# </div>
#
# <script>
#  requirejs.config({
#      paths: {
#        'JSRootCore' : 'https://root.cern.ch/js/notebook//scripts/JSRootCore',
#      }
#    });
#  require(['JSRootCore'],
#      function(Core) {
# ...

# %% [markdown]
# ## Fill Time stable beam is the time of the start of stable beam

# %%
c = R.TCanvas("c1")
t.Draw("fill_time/fill_time_stablebeam", "fill_time>0")
c.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c1
# <div id="root_plot_13"
#      style="width: 696px; height: 472px">
# </div>
#
# <script>
#  requirejs.config({
#      paths: {
#        'JSRootCore' : 'https://root.cern.ch/js/notebook//scripts/JSRootCore',
#      }
#    });
#  require(['JSRootCore'],
#      function(Core) {
# ...

# %%
c = R.TCanvas("c1")
t.Draw("fill_num", "fill_num>0")
c.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c1
# <div id="root_plot_44"
#      style="width: 696px; height: 472px">
# </div>
#
# <script>
#  requirejs.config({
#      paths: {
#        'JSRootCore' : 'https://root.cern.ch/js/notebook//scripts/JSRootCore',
#      }
#    });
#  require(['JSRootCore'],
#      function(Core) {
# ...

# %% [markdown]
# ## Run num infill is indeed the order of the run inside the fill

# %%
c = R.TCanvas("c1")
t.Draw("run_num_infill")
c.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c1

# %% [markdown]
# ## 4 run type?
# Cosmics, stable beam, ??

# %%
c = R.TCanvas("c1")
t.Draw("run_type")
c.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c1
# <div id="root_plot_9"
#      style="width: 696px; height: 472px">
# </div>
#
# <script>
#  requirejs.config({
#      paths: {
#        'JSRootCore' : 'https://root.cern.ch/js/notebook//scripts/JSRootCore',
#      }
#    });
#  require(['JSRootCore'],
#      function(Core) {
# ...

# %% [markdown]
# ## Trasparency plot of 1 xtal

# %%
ix = 10
iy = 20
iz = 0

c = R.TCanvas("c1")
t.Draw("nrv:time[0]", "ix=={} && iy=={} && iz=={}".format(ix, iy, iz))
c.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c1
# <div id="root_plot_3"
#      style="width: 696px; height: 472px">
# </div>
#
# <script>
#  requirejs.config({
#      paths: {
#        'JSRootCore' : 'https://root.cern.ch/js/notebook//scripts/JSRootCore',
#      }
#    });
#  require(['JSRootCore'],
#      function(Core) {
# ...

# %%
ix = 10
iy = 20
iz = 0

c = R.TCanvas("c1")
t.Draw("nrv:time[0]:(time[0]-fill_time)", "fill_time>0 && ix=={} && iy=={} && iz=={}".format(ix, iy, iz))
c.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c1
# <div id="root_plot_8"
#      style="width: 696px; height: 472px">
# </div>
#
# <script>
#  requirejs.config({
#      paths: {
#        'JSRootCore' : 'https://root.cern.ch/js/notebook//scripts/JSRootCore',
#      }
#    });
#  require(['JSRootCore'],
#      function(Core) {
# ...
