# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import pandas as pd
import numpy as np
from pprint import pprint
from collections import namedtuple

mpl.rcParams['figure.figsize'] = (5,4)
mpl.rcParams['figure.dpi'] = 150
mpl.rcParams["image.origin"] = 'lower'
 
# %matplotlib notebook

# %%
# Put your data folder
data_folder = "/eos/user/d/dvalsecc/www/ECAL/Transparency/data_v1"

# %%
# Array with filtered crystals
data = np.load(f"{data_folder}/transp_10min_ix0.npy", allow_pickle=True)
metadata = pd.read_csv(f"{data_folder}/fill_metadata_2017_10min.csv")

# %%
# Filter problematic points
data = data[data != -1]
metadata = metadata.iloc[:len(data)][data!=-1]

# %%
metadata.head()
# Out:
#    Unnamed: 0  in_fill        time  lumi_inst  lumi_in_fill  \
# 0           0        1  1495541393    0.12584       0.12584
# 1           1        0  1495541993    0.00000       0.00000
# 2           2        0  1495542593    0.00000       0.00000
# 3           3        0  1495543193    0.00000       0.00000
# 4           4        0  1495543793    0.00000       0.00000
#
#    lumi_since_last_point  lumi_last_fill  fill_num  time_in_fill  \
# 0               0.125840        0.000000      5697             0
# 1               0.493614        0.493614         0             0
# 2               0.000000        0.493614         0             0
# 3               0.000000        0.493614         0             0
# 4               0.000000        0.493614         0             0
#
#    time_in_fill_stable  time_from_last_fill  last_dump_duration  \
# 0                  0.0                    0                   0
# 1                  0.0                  533                 533
# 2                  0.0                 1133                1133
# 3                  0.0                 1733                1733
# 4                  0.0                 2333                2333
#
#    last_fill_duration
# 0                   0
# 1                  67
# 2                  67
# 3                  67
# 4                  67

# %%
plt.plot(metadata.time, data, "bo-", markersize=2)
# Out:
# <img src="data:image/png;base64,..." width="749.8333333333334">
